# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
Matches=pd.read_csv("matches.csv")

# %%
Matches
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
Matches.shape
# Out:
# (756, 18)

# %% [markdown]
# # How many rows and columns are there?

# %%
Matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
Matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
print("No of Rows are:",len(Matches))
print("No of columns are:",len(Matches.columns))
# Out:
# No of Rows are: 756
# No of columns are: 18

# %%
Matches.describe
# Out:
# <bound method NDFrame.describe of         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %% [markdown]
# # 756 rows are there that means we have details 756 matches that takes place between 2008-2019

# %%
print("No of matches that takes place between 2008-2019 were:",len(Matches))
# Out:
# No of matches that takes place between 2008-2019 were: 756

# %% [markdown]
# # It looks like between 2011-2013.Total no matches exceeds 70.That because in these periods(2011-2013)there were 10 teams(kochi tuskers kerala and pune warriors india were the new additions

# %%
year_wise_analysing=Matches.groupby('season')
year_wise_analysing.count()
year_wise_analysing['id'].count().plot(kind='bar')

# %%
year_wise_analysing['id'].count()
# Out:
# season
# 2008    58
# 2009    57
# 2010    60
# 2011    73
# 2012    74
# 2013    76
# 2014    60
# 2015    59
# 2016    60
# 2017    59
# 2018    60
# 2019    60
# Name: id, dtype: int64

# %%
Matches.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %% [markdown]
# # from the below plot we can find huge missing values are there in umpire 3 columns .we can remove the column it will not create a impact on predicting the matches.

# %%
sns.heatmap(Matches.isnull(),yticklabels=False,cbar=False,cmap='PiYG')

# %%
Matches.head(2)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   player_of_match                                      venue         umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2 umpire3
# 0  NJ Llong     NaN
# 1    S Ravi     NaN

# %% [markdown]
# #  Removed the columns containing more missing values and have less impact on the predicting matches

# %%
Matches=Matches.drop(['umpire3','city'],axis=1)

# %%
Matches.head(2)
# Out:
#    id  season        date                team1                        team2  \
# 0   1    2017  2017-04-05  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1   2    2017  2017-04-06       Mumbai Indians       Rising Pune Supergiant
#
#                    toss_winner toss_decision  result  dl_applied  \
# 0  Royal Challengers Bangalore         field  normal           0
# 1       Rising Pune Supergiant         field  normal           0
#
#                    winner  win_by_runs  win_by_wickets player_of_match  \
# 0     Sunrisers Hyderabad           35               0    Yuvraj Singh
# 1  Rising Pune Supergiant            0               7       SPD Smith
#
#                                        venue         umpire1   umpire2
# 0  Rajiv Gandhi International Stadium, Uppal     AY Dandekar  NJ Llong
# 1    Maharashtra Cricket Association Stadium  A Nand Kishore    S Ravi

# %%
sns.heatmap(Matches.isnull(),yticklabels=False,cbar=False,cmap='PiYG')

# %% [markdown]
# # Today's match is between RR and CSK.so we only want information between the matches that take place between them

# %%
Matches
# Out:
#         id  season        date                        team1  \
# 0        1    2017  2017-04-05          Sunrisers Hyderabad
# 1        2    2017  2017-04-06               Mumbai Indians
# 2        3    2017  2017-04-07                Gujarat Lions
# 3        4    2017  2017-04-08       Rising Pune Supergiant
# 4        5    2017  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...         ...                          ...
# 751  11347    2019    05/05/19        Kolkata Knight Riders
# 752  11412    2019    07/05/19          Chennai Super Kings
# 753  11413    2019    08/05/19          Sunrisers Hyderabad
# 754  11414    2019    10/05/19               Delhi Capitals
# 755  11415    2019    12/05/19               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1         Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
RR_CSK1=Matches.loc[(Matches['team1']=='Rajasthan Royals')&(Matches['team2'] =='Chennai Super Kings')]

# %%
RR_CSK2=Matches.loc[(Matches['team2']=='Rajasthan Royals')&(Matches['team1'] =='Chennai Super Kings')]

# %%
RR_CSK=RR_CSK1.append(RR_CSK2)

# %% [markdown]
# #   Complete details of matches that takes place between RR and CSK

# %%
RR_CSK
# Out:
#         id  season        date                team1                team2  \
# 109    110    2008  2008-05-24     Rajasthan Royals  Chennai Super Kings
# 151    152    2009  2009-05-09     Rajasthan Royals  Chennai Super Kings
# 197    198    2010  2010-03-28     Rajasthan Royals  Chennai Super Kings
# 275    276    2011  2011-05-04     Rajasthan Royals  Chennai Super Kings
# 333    334    2012  2012-04-21     Rajasthan Royals  Chennai Super Kings
# 360    361    2012  2012-05-10     Rajasthan Royals  Chennai Super Kings
# 409    410    2013  2013-04-22     Rajasthan Royals  Chennai Super Kings
# 493    494    2014  2014-05-13     Rajasthan Royals  Chennai Super Kings
# 720  11316    2019    11/04/19     Rajasthan Royals  Chennai Super Kings
# 82      83    2008  2008-05-04  Chennai Super Kings     Rajasthan Royals
# 116    117    2008  2008-06-01  Chennai Super Kings     Rajasthan Royals
# 136    137    2009  2009-04-30  Chennai Super Kings     Rajasthan Royals
# ...

# %% [markdown]
# # It looks like RR and CSK played 21 matches against each other

# %%
won_by_runs_wickest=RR_CSK.groupby('id')

# %%
won_by_runs_wickest.sum()
# Out:
#        season  dl_applied  win_by_runs  win_by_wickets
# id
# 83       2008           0            0               8
# 110      2008           0           10               0
# 117      2008           0            0               3
# 137      2009           0           38               0
# 152      2009           0            0               7
# 198      2010           0           17               0
# 206      2010           0           23               0
# 276      2011           0            0               8
# 285      2011           0           63               0
# 334      2012           0            0               7
# 361      2012           0            0               4
# 410      2013           0            0               5
# 442      2013           0            0               5
# 467      2014           0            7               0
# 494      2014           0            0               5
# 533      2015           0            0               8
# ...

# %%
RR_CSK['id'].value_counts()
# Out:
# 285      1
# 137      1
# 442      1
# 11316    1
# 7936     1
# 198      1
# 334      1
# 7910     1
# 361      1
# 11148    1
# 110      1
# 494      1
# 563      1
# 83       1
# 276      1
# 117      1
# 467      1
# 206      1
# 152      1
# 410      1
# 533      1
# Name: id, dtype: int64

# %%
RR_CSK.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21 entries, 109 to 707
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21 non-null     int64
#  1   season           21 non-null     int64
#  2   date             21 non-null     object
#  3   team1            21 non-null     object
#  4   team2            21 non-null     object
#  5   toss_winner      21 non-null     object
#  6   toss_decision    21 non-null     object
#  7   result           21 non-null     object
#  8   dl_applied       21 non-null     int64
#  9   winner           21 non-null     object
#  10  win_by_runs      21 non-null     int64
#  11  win_by_wickets   21 non-null     int64
#  12  player_of_match  21 non-null     object
#  13  venue            21 non-null     object
#  14  umpire1          21 non-null     object
#  15  umpire2          21 non-null     object
# dtypes: int64(5), object(11)
# ...

# %%
RR_CSK.describe
# Out:
# <bound method NDFrame.describe of         id  season        date                team1                team2  \
# 109    110    2008  2008-05-24     Rajasthan Royals  Chennai Super Kings
# 151    152    2009  2009-05-09     Rajasthan Royals  Chennai Super Kings
# 197    198    2010  2010-03-28     Rajasthan Royals  Chennai Super Kings
# 275    276    2011  2011-05-04     Rajasthan Royals  Chennai Super Kings
# 333    334    2012  2012-04-21     Rajasthan Royals  Chennai Super Kings
# 360    361    2012  2012-05-10     Rajasthan Royals  Chennai Super Kings
# 409    410    2013  2013-04-22     Rajasthan Royals  Chennai Super Kings
# 493    494    2014  2014-05-13     Rajasthan Royals  Chennai Super Kings
# 720  11316    2019    11/04/19     Rajasthan Royals  Chennai Super Kings
# 82      83    2008  2008-05-04  Chennai Super Kings     Rajasthan Royals
# 116    117    2008  2008-06-01  Chennai Super Kings     Rajasthan Royals
# ...

# %%
print("No of matches that takes place between MI and KKR:",len(RR_CSK))
# Out:
# No of matches that takes place between MI and KKR: 21

# %% [markdown]
# # Below plot gives the details of the match that takes place between RR and CSK

# %%
sns.pairplot(RR_CSK)

# %% [markdown]
# # Now Time to answer the questions that were asked in the widhya ipl

# %%
RR_CSK['toss_winner'].value_counts()
# Out:
# Rajasthan Royals       14
# Chennai Super Kings     7
# Name: toss_winner, dtype: int64

# %% [markdown]
# # Sometimes Toss plays an crucial role in deciding the winner.RR won the Toss 14 times and CSK won it 7 times

# %%
RR_CSK['toss_winner'].value_counts().plot(kind='bar')

# %%
print("No of times toss won by both teams:")
RR_CSK['toss_winner'].value_counts()
# Out:
# No of times toss won by both teams:
# Rajasthan Royals       14
# Chennai Super Kings     7
# Name: toss_winner, dtype: int64

# %% [markdown]
# # From 21 matches Rajastan Royals win 5 Times by Batting first and 2 times by Batting second whereas Chennai Super Kings win 7 times by batting first and 7 times by batting second.

# %%
import sys
sys.setrecursionlimit(10000) 
sns.set({'figure.figsize':(15,5)})
sns.countplot(x='toss_decision',hue='winner',data=RR_CSK,palette='RdBu_r')

# %%
RR_CSK['winner'].value_counts()
# Out:
# Chennai Super Kings    14
# Rajasthan Royals        7
# Name: winner, dtype: int64

# %% [markdown]
# # CSK win 14 times against RR and the latter win 7 times against csk.it's clear that CSk dominating RR

# %%
RR_CSK['winner'].value_counts().plot(kind='bar')

# %% [markdown]
# # Complete details RR_CSK using sweetviz library

# %%
import sweetviz 
my_report=sweetviz.analyze([RR_CSK,"RR_CSK"])
# Out:
# :FEATURES DONE:                    |                     | [  0%]   00:05  -> (00:00 left)
# :PAIRWISE DONE:                    |█████████████████████| [100%]   00:00  -> (00:00 left)
# Creating Associations graph... DONE!

# %%
my_report.show_html()

# %%
print("From 21 matches csk win 14 matches and Rajastan Royals 7 times")
# Out:
# From 21 matches csk win 14 matches and Rajastan Royals 7 times

# %% [markdown]
# # Now it's time to move into deliveries data sets

# %%
Deliveries=pd.read_csv("deliveries.csv")

# %%
Deliveries.head(5)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
Deliveries.tail(5)
# Out:
#         match_id  inning         batting_team    bowling_team  over  ball  \
# 179073     11415       2  Chennai Super Kings  Mumbai Indians    20     2
# 179074     11415       2  Chennai Super Kings  Mumbai Indians    20     3
# 179075     11415       2  Chennai Super Kings  Mumbai Indians    20     4
# 179076     11415       2  Chennai Super Kings  Mumbai Indians    20     5
# 179077     11415       2  Chennai Super Kings  Mumbai Indians    20     6
#
#           batsman non_striker      bowler  is_super_over  ...  bye_runs  \
# 179073  RA Jadeja   SR Watson  SL Malinga              0  ...         0
# 179074  SR Watson   RA Jadeja  SL Malinga              0  ...         0
# 179075  SR Watson   RA Jadeja  SL Malinga              0  ...         0
# 179076  SN Thakur   RA Jadeja  SL Malinga              0  ...         0
# 179077  SN Thakur   RA Jadeja  SL Malinga              0  ...         0
#
#         legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
Deliveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %% [markdown]
# # Filtering the match details that only takes place between Rajastan Royals and Chennai Super Kings

# %%
Rajastan_Chennai1=Deliveries.loc[(Deliveries['batting_team' ] =='Rajasthan Royals' ) & (Deliveries['bowling_team'] == 'Chennai Super Kings')]

# %%
Rajastan_Chennai2=Deliveries.loc[(Deliveries['bowling_team' ] =='Rajasthan Royals' ) & (Deliveries['batting_team'] == 'Chennai Super Kings')]

# %%
Rajastan_Chennai=Rajastan_Chennai1.append(Rajastan_Chennai2)

# %%
Rajastan_Chennai
# Out:
#         match_id  inning         batting_team         bowling_team  over  \
# 19457         83       2     Rajasthan Royals  Chennai Super Kings     1
# 19458         83       2     Rajasthan Royals  Chennai Super Kings     1
# 19459         83       2     Rajasthan Royals  Chennai Super Kings     1
# 19460         83       2     Rajasthan Royals  Chennai Super Kings     1
# 19461         83       2     Rajasthan Royals  Chennai Super Kings     1
# ...          ...     ...                  ...                  ...   ...
# 170825     11316       2  Chennai Super Kings     Rajasthan Royals    20
# 170826     11316       2  Chennai Super Kings     Rajasthan Royals    20
# 170827     11316       2  Chennai Super Kings     Rajasthan Royals    20
# 170828     11316       2  Chennai Super Kings     Rajasthan Royals    20
# 170829     11316       2  Chennai Super Kings     Rajasthan Royals    20
#
#         ball    batsman  non_striker     bowler  is_super_over  ...  bye_runs  \
# ...

# %%
Rajastan_Chennai['match_id'].value_counts()
# Out:
# 7936     252
# 11148    251
# 117      250
# 410      248
# 110      248
# 467      248
# 206      247
# 563      247
# 494      246
# 11316    246
# 285      246
# 198      245
# 7910     245
# 334      244
# 361      243
# 137      243
# 276      238
# 152      238
# 533      234
# 442      227
# 83       209
# Name: match_id, dtype: int64

# %%
Rajastan_Chennai.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5095 entries, 19457 to 170829
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   match_id          5095 non-null   int64
#  1   inning            5095 non-null   int64
#  2   batting_team      5095 non-null   object
#  3   bowling_team      5095 non-null   object
#  4   over              5095 non-null   int64
#  5   ball              5095 non-null   int64
#  6   batsman           5095 non-null   object
#  7   non_striker       5095 non-null   object
#  8   bowler            5095 non-null   object
#  9   is_super_over     5095 non-null   int64
#  10  wide_runs         5095 non-null   int64
#  11  bye_runs          5095 non-null   int64
#  12  legbye_runs       5095 non-null   int64
#  13  noball_runs       5095 non-null   int64
#  14  penalty_runs      5095 non-null   int64
#  15  batsman_runs      5095 non-null   int64
# ...

# %%
Rajastan_Chennai.describe
# Out:
# <bound method NDFrame.describe of         match_id  inning         batting_team         bowling_team  over  \
# 19457         83       2     Rajasthan Royals  Chennai Super Kings     1
# 19458         83       2     Rajasthan Royals  Chennai Super Kings     1
# 19459         83       2     Rajasthan Royals  Chennai Super Kings     1
# 19460         83       2     Rajasthan Royals  Chennai Super Kings     1
# 19461         83       2     Rajasthan Royals  Chennai Super Kings     1
# ...          ...     ...                  ...                  ...   ...
# 170825     11316       2  Chennai Super Kings     Rajasthan Royals    20
# 170826     11316       2  Chennai Super Kings     Rajasthan Royals    20
# 170827     11316       2  Chennai Super Kings     Rajasthan Royals    20
# 170828     11316       2  Chennai Super Kings     Rajasthan Royals    20
# 170829     11316       2  Chennai Super Kings     Rajasthan Royals    20
#
# ...

# %% [markdown]
# # Check For any Null values

# %%
Rajastan_Chennai.isnull().sum()
# Out:
# match_id               0
# inning                 0
# batting_team           0
# bowling_team           0
# over                   0
# ball                   0
# batsman                0
# non_striker            0
# bowler                 0
# is_super_over          0
# wide_runs              0
# bye_runs               0
# legbye_runs            0
# noball_runs            0
# penalty_runs           0
# batsman_runs           0
# extra_runs             0
# total_runs             0
# player_dismissed    4853
# dismissal_kind      4853
# fielder             4914
# dtype: int64

# %% [markdown]
# # Looks like we have huge null(NaN) values in  player_dismissed,dismissal_kind,fielder columns

# %%
sns.heatmap(Rajastan_Chennai.isnull(),yticklabels=False,cbar=False,cmap='PiYG')

# %% [markdown]
# # Replace the NaN values to 0

# %%
Rajastan_Chennai.fillna(0,inplace=True)

# %% [markdown]
# # Now it's clear

# %%
sns.heatmap(Rajastan_Chennai.isnull(),yticklabels=False,cbar=False,cmap='PiYG')

# %% [markdown]
# # # Let's try covariance to find relation among features

# %%
Rajastan_Chennai.cov()
# Out:
#                    match_id    inning        over       ball  is_super_over  \
# match_id       1.405694e+07  6.116545  267.117855  77.724751            0.0
# inning         6.116545e+00  0.249951   -0.096406  -0.003271            0.0
# over           2.671179e+02 -0.096406   32.398266   0.031865            0.0
# ball           7.772475e+01 -0.003271    0.031865   3.263335            0.0
# is_super_over  0.000000e+00  0.000000    0.000000   0.000000            0.0
# wide_runs      7.009022e+00 -0.000504    0.022518   0.014514            0.0
# bye_runs      -6.436046e+00 -0.000458   -0.007988   0.002281            0.0
# legbye_runs   -1.310689e+01 -0.000006   -0.016257   0.002191            0.0
# noball_runs    1.689628e+00  0.000335    0.016287  -0.002321            0.0
# penalty_runs   0.000000e+00  0.000000    0.000000   0.000000            0.0
# batsman_runs   1.472208e+02 -0.008710    0.701087   0.029242            0.0
# ...

# %% [markdown]
# # it's diffult to interpret covariance.Let's try correlation.Correlation clearly mentions using discrete values 1=positively correlated,-1=Negatively correlated,0=No correlation.

# %%
Rajastan_Chennai.corr()
# Out:
#                match_id    inning      over      ball  is_super_over  \
# match_id       1.000000  0.003263  0.012517  0.011476            NaN
# inning         0.003263  1.000000 -0.033878 -0.003622            NaN
# over           0.012517 -0.033878  1.000000  0.003099            NaN
# ball           0.011476 -0.003622  0.003099  1.000000            NaN
# is_super_over       NaN       NaN       NaN       NaN            NaN
# wide_runs      0.006778 -0.003655  0.014343  0.029129            NaN
# bye_runs      -0.017882 -0.009537 -0.014620  0.013154            NaN
# legbye_runs   -0.018591 -0.000060 -0.015189  0.006450            NaN
# noball_runs    0.007033  0.010468  0.044659 -0.020051            NaN
# penalty_runs        NaN       NaN       NaN       NaN            NaN
# batsman_runs   0.024876 -0.011036  0.078031  0.010255            NaN
# extra_runs    -0.008267 -0.003613  0.007312  0.026369            NaN
# total_runs     0.023037 -0.011834  0.079629  0.016094            NaN
#
# ...

# %% [markdown]
# # # Ball by Ball Details of RR VS CSK From 21 matches

# %%
Rajastan_Chennai
# Out:
#         match_id  inning         batting_team         bowling_team  over  \
# 19457         83       2     Rajasthan Royals  Chennai Super Kings     1
# 19458         83       2     Rajasthan Royals  Chennai Super Kings     1
# 19459         83       2     Rajasthan Royals  Chennai Super Kings     1
# 19460         83       2     Rajasthan Royals  Chennai Super Kings     1
# 19461         83       2     Rajasthan Royals  Chennai Super Kings     1
# ...          ...     ...                  ...                  ...   ...
# 170825     11316       2  Chennai Super Kings     Rajasthan Royals    20
# 170826     11316       2  Chennai Super Kings     Rajasthan Royals    20
# 170827     11316       2  Chennai Super Kings     Rajasthan Royals    20
# 170828     11316       2  Chennai Super Kings     Rajasthan Royals    20
# 170829     11316       2  Chennai Super Kings     Rajasthan Royals    20
#
#         ball    batsman  non_striker     bowler  is_super_over  ...  bye_runs  \
# ...

# %%
Complete_Details=Rajastan_Chennai.groupby('match_id')

# %%
Complete_Details.sum()
# Out:
#           inning  over  ball  is_super_over  wide_runs  bye_runs  legbye_runs  \
# match_id
# 83           302  1879   756              0         16         4            7
# 110          374  2597   896              0          4         1            7
# 117          376  2657   913              0          8         2            8
# 137          363  2537   867              0          5         0            7
# 152          354  2403   857              0          9         0            7
# 198          368  2563   875              0          5         0            4
# 206          372  2611   890              0          6         8            6
# 276          354  2431   851              0          5         0            5
# 285          367  2545   888              0         11         0            2
# 334          365  2568   869              0         12         1            3
# 361          360  2434   892              0         18         0            6
# ...

# %% [markdown]
# # From the correlation plot we can clearly see that extra runs,wide runs ,bye runs are correlated and apart from that batsman runs column and total_runs columns are highly correlated

# %%
plt.figure(figsize=(10,5))
sns.heatmap(Rajastan_Chennai.corr(),yticklabels=True,annot=True)

# %% [markdown]
# # How Many Runs will RR score in the First 6overs?

# %%
Rajastan_Chennai1
# Out:
#         match_id  inning      batting_team         bowling_team  over  ball  \
# 19457         83       2  Rajasthan Royals  Chennai Super Kings     1     1
# 19458         83       2  Rajasthan Royals  Chennai Super Kings     1     2
# 19459         83       2  Rajasthan Royals  Chennai Super Kings     1     3
# 19460         83       2  Rajasthan Royals  Chennai Super Kings     1     4
# 19461         83       2  Rajasthan Royals  Chennai Super Kings     1     5
# ...          ...     ...               ...                  ...   ...   ...
# 170701     11316       1  Rajasthan Royals  Chennai Super Kings    20     2
# 170702     11316       1  Rajasthan Royals  Chennai Super Kings    20     3
# 170703     11316       1  Rajasthan Royals  Chennai Super Kings    20     4
# 170704     11316       1  Rajasthan Royals  Chennai Super Kings    20     5
# 170705     11316       1  Rajasthan Royals  Chennai Super Kings    20     6
#
# ...

# %%
Rajastan_Chennai1.head(2)
# Out:
#        match_id  inning      batting_team         bowling_team  over  ball  \
# 19457        83       2  Rajasthan Royals  Chennai Super Kings     1     1
# 19458        83       2  Rajasthan Royals  Chennai Super Kings     1     2
#
#         batsman  non_striker   bowler  is_super_over  ...  bye_runs  \
# 19457  GC Smith  SA Asnodkar  M Ntini              0  ...         0
# 19458  GC Smith  SA Asnodkar  M Ntini              0  ...         0
#
#        legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# 19457            0            0             0             0           0
# 19458            0            0             0             0           0
#
#        total_runs  player_dismissed dismissal_kind fielder
# 19457           0               NaN            NaN     NaN
# 19458           0               NaN            NaN     NaN
#
# [2 rows x 21 columns]

# %%
RR_First_6_Overs_Runs=Rajastan_Chennai1.loc[(Rajastan_Chennai1['over']<=6)]

# %%
RR_First_6_Overs_Runs
# Out:
#         match_id  inning      batting_team         bowling_team  over  ball  \
# 19457         83       2  Rajasthan Royals  Chennai Super Kings     1     1
# 19458         83       2  Rajasthan Royals  Chennai Super Kings     1     2
# 19459         83       2  Rajasthan Royals  Chennai Super Kings     1     3
# 19460         83       2  Rajasthan Royals  Chennai Super Kings     1     4
# 19461         83       2  Rajasthan Royals  Chennai Super Kings     1     5
# ...          ...     ...               ...                  ...   ...   ...
# 170616     11316       1  Rajasthan Royals  Chennai Super Kings     6     2
# 170617     11316       1  Rajasthan Royals  Chennai Super Kings     6     3
# 170618     11316       1  Rajasthan Royals  Chennai Super Kings     6     4
# 170619     11316       1  Rajasthan Royals  Chennai Super Kings     6     5
# 170620     11316       1  Rajasthan Royals  Chennai Super Kings     6     6
#
# ...

# %%
RR_First_6_Over_Runs=RR_First_6_Overs_Runs.groupby('total_runs')

# %%
RR_First_6_Over_Runs.sum()
# Out:
#             match_id  inning  over  ball  is_super_over  wide_runs  bye_runs  \
# total_runs
# 0             805462     577  1211  1291              0          0         0
# 1             373545     340   792   791              0          8         1
# 2             100838      60   129   137              0          7         0
# 3              10100      11    22    19              0          0         0
# 4             272366     190   443   426              0          0         4
# 5                779       3     5     5              0          5         0
# 6              62518      34    91    99              0          0         0
# 10             11316       1     2     5              0          5         0
#
#             legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs
# total_runs
# 0                     0            0             0             0           0
# 1                     8            1             0           197          18
# ...

# %%
RR_First_6_Overs_Runs['total_runs'].value_counts()
# Out:
# 0     367
# 1     215
# 4     123
# 2      37
# 6      23
# 3       6
# 5       2
# 10      1
# Name: total_runs, dtype: int64

# %%
Ten_runs_in_single_ball=RR_First_6_Overs_Runs.loc[(RR_First_6_Overs_Runs['total_runs']==10)]

# %% [markdown]
# # Ten runs are not possible to score in a single Ball.There is an error we need to reduce 5runs from 10runs.scoring 5runs in a single ball is possible(when a  bowler bowls a ball if the ball didn't touch the batsman bat and then if the keeper fails to stop(touch) the ball going to the boundary.Then the batting team ll awarded 5 runs ll be come under extra runs.

# %%
Ten_runs_in_single_ball
# Out:
#         match_id  inning      batting_team         bowling_team  over  ball  \
# 170594     11316       1  Rajasthan Royals  Chennai Super Kings     2     5
#
#           batsman non_striker     bowler  is_super_over  ...  bye_runs  \
# 170594  AM Rahane  JC Buttler  M Santner              0  ...         0
#
#         legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# 170594            0            0             0             5           5
#
#         total_runs  player_dismissed dismissal_kind fielder
# 170594          10               NaN            NaN     NaN
#
# [1 rows x 21 columns]

# %%
RR_First_6_Overs_Runs['total_runs'].value_counts().plot(kind='bar')

# %% [markdown]
# # ways of Runs scored by RR in First 6 overs  (1's-215,2's=37,3's=6,4's=123,5's=3,6's=23)-Error in 10runs(should be 5runs only come under extra runs)

# %%
RR_First_6_Overs_Runs['total_runs'].value_counts()
# Out:
# 0     367
# 1     215
# 4     123
# 2      37
# 6      23
# 3       6
# 5       2
# 10      1
# Name: total_runs, dtype: int64

# %%
RR_First_6_Overs_Runs['total_runs'].sum()
# Out:
# 957

# %%
print("Average Runs scored by Rajastan Royals in First 6 overs from 21 matches",957-5//21)
# Out:
# Average Runs scored by Rajastan Royals in First 6 overs from 21 matches 957

# %% [markdown]
# # Match wise Runs scored by RR Against Csk in First Six overs

# %%
RR_Runs_match_Wise=RR_First_6_Overs_Runs.groupby('match_id')['total_runs']

# %%
RR_Runs_match_Wise.sum()
# Out:
# match_id
# 83       44
# 110      67
# 117      41
# 137      38
# 152      34
# 198      58
# 206      62
# 276      47
# 285      48
# 334      41
# 361      28
# 410      55
# 442      24
# 467      38
# 494      42
# 533      47
# 563      40
# 7910     37
# 7936     58
# 11148    48
# 11316    60
# Name: total_runs, dtype: int64

# %% [markdown]
# # Below plots used to tell the runs scored by RR in First 6 overs againstCsk.RR  scored (36,41,47,48,56)runs two times from 21 matches.

# %%
sns.set()
plt.figure(figsize=(26,5))
sns.countplot(RR_Runs_match_Wise.sum(),data=Rajastan_Chennai1)

# %% [markdown]
# # What will be Deepak chahar's economy rate?

# %%
Deepak_Chahar_Economy_Rate=Rajastan_Chennai1.loc[(Rajastan_Chennai1['bowler']=='DL Chahar')]

# %%
Deepak_Chahar_Economy_Rate
# Out:
#         match_id  inning      batting_team         bowling_team  over  ball  \
# 154358      7910       2  Rajasthan Royals  Chennai Super Kings     1     1
# 154359      7910       2  Rajasthan Royals  Chennai Super Kings     1     2
# 154360      7910       2  Rajasthan Royals  Chennai Super Kings     1     3
# 154361      7910       2  Rajasthan Royals  Chennai Super Kings     1     4
# 154362      7910       2  Rajasthan Royals  Chennai Super Kings     1     5
# ...          ...     ...               ...                  ...   ...   ...
# 170695     11316       1  Rajasthan Royals  Chennai Super Kings    19     2
# 170696     11316       1  Rajasthan Royals  Chennai Super Kings    19     3
# 170697     11316       1  Rajasthan Royals  Chennai Super Kings    19     4
# 170698     11316       1  Rajasthan Royals  Chennai Super Kings    19     5
# 170699     11316       1  Rajasthan Royals  Chennai Super Kings    19     6
#
# ...

# %%
Deepak_Chahar_Economy_Rate['total_runs'].value_counts()
# Out:
# 0    31
# 1    27
# 2     9
# 4     8
# 6     2
# Name: total_runs, dtype: int64

# %%
Deepak_Chahar_Economy_Rate_=Deepak_Chahar_Economy_Rate.groupby('match_id')['total_runs']

# %% [markdown]
# # Deepak Chahar gave 89 runs from 3 matches with an economy of 4.92

# %%
sns.distplot(Deepak_Chahar_Economy_Rate['total_runs'])

# %% [markdown]
# # Comparision of runs given by Deepak chahar throught extra's and batsman runs

# %%
sns.jointplot(x='batsman_runs',y='total_runs',kind='reg',data=Deepak_Chahar_Economy_Rate)

# %%
sns.jointplot(x='batsman_runs',y='total_runs',kind='hex',data=Deepak_Chahar_Economy_Rate)

# %%
sns.jointplot(x='batsman_runs',y='total_runs',kind='kde',data=Deepak_Chahar_Economy_Rate)

# %%
sns.barplot(x='bowler',y='total_runs',data=Deepak_Chahar_Economy_Rate)

# %%
Deepak_Chahar_Economy_Rate_.sum()
# Out:
# match_id
# 7910     34
# 11148    20
# 11316    35
# Name: total_runs, dtype: int64

# %%
print("Against Rajastan Royals Deepak Chahar gave  a total of 89 runs from three matches",((34/6)+(20/6)+(35/6))/3)
# Out:
# Against Rajastan Royals Deepak Chahar gave  a total of 89 runs from three matches 4.944444444444444

# %% [markdown]
# # How many wickets ll jofra Archer take in the death overs?

# %%
Jofra_Archer_In_Death_Overs=Rajastan_Chennai2.loc[(Rajastan_Chennai2['bowler']=='J Archer')]

# %%
Jofra_Archer_in_Death_Overs=Jofra_Archer_In_Death_Overs.loc[(Jofra_Archer_In_Death_Overs['over']>=15)]

# %%
Jofra_Archer_in_Death_Overs
# Out:
#         match_id  inning         batting_team      bowling_team  over  ball  \
# 160544      7936       1  Chennai Super Kings  Rajasthan Royals    17     1
# 160545      7936       1  Chennai Super Kings  Rajasthan Royals    17     2
# 160546      7936       1  Chennai Super Kings  Rajasthan Royals    17     3
# 160547      7936       1  Chennai Super Kings  Rajasthan Royals    17     4
# 160548      7936       1  Chennai Super Kings  Rajasthan Royals    17     5
# 160549      7936       1  Chennai Super Kings  Rajasthan Royals    17     6
# 160550      7936       1  Chennai Super Kings  Rajasthan Royals    17     7
# 160558      7936       1  Chennai Super Kings  Rajasthan Royals    19     1
# 160559      7936       1  Chennai Super Kings  Rajasthan Royals    19     2
# 160560      7936       1  Chennai Super Kings  Rajasthan Royals    19     3
# 160561      7936       1  Chennai Super Kings  Rajasthan Royals    19     4
# ...

# %%
Jofra_Archer_in_Death_Overs.groupby('match_id')['dismissal_kind']

# %%
Jofra_Archer_in_Death_overs=Jofra_Archer_in_Death_Overs.groupby('match_id')

# %%
Jofra_Archer_in_Death_overs.sum()
# Out:
#           inning  over  ball  is_super_over  wide_runs  bye_runs  legbye_runs  \
# match_id
# 7936          13   233    49              0          1         0            0
# 11148         12   216    42              0          0         0            0
# 11316         24   216    42              0          0         0            4
#
#           noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs
# match_id
# 7936                0             0            19           1          20
# 11148               0             0            15           0          15
# 11316               0             0            19           4          23

# %%
Jofra_Archer_in_Death_Overs['over'].value_counts()
# Out:
# 17    19
# 19    18
# Name: over, dtype: int64

# %%
Jofra_Archer_in_Death_Overs['dismissal_kind'].value_counts()
# Out:
# caught    1
# Name: dismissal_kind, dtype: int64

# %%
Csk_Runs_inning_Wise.sum()
# Out:
# inning
# 1    2139
# 2    1303
# Name: total_runs, dtype: int64

# %%
print("jofra_Archer took 1 wicket from his death overs against csk")
# Out:
# jofra_Archer took 1 wicket from his death overs against csk

# %%
sns.distplot(Jofra_Archer_in_Death_Overs['total_runs'])

# %%
sns.boxplot(x='bowler',y='total_runs',hue='dismissal_kind',data=Jofra_Archer_in_Death_Overs)

# %%
sns.boxplot(x='batsman_runs',y='total_runs',data=Jofra_Archer_in_Death_Overs)

# %% [markdown]
# # What ll steve smith strike rate during the match?

# %%
Steve_Smith_Strike_Rate=Rajastan_Chennai1.loc[(Rajastan_Chennai1['batsman']=='SPD Smith')]

# %%
Steve_Smith_Strike_Rate
# Out:
#         match_id  inning      batting_team         bowling_team  over  ball  \
# 110728       467       2  Rajasthan Royals  Chennai Super Kings     7     6
# 110732       467       2  Rajasthan Royals  Chennai Super Kings     8     4
# 110736       467       2  Rajasthan Royals  Chennai Super Kings     9     2
# 110737       467       2  Rajasthan Royals  Chennai Super Kings     9     3
# 110738       467       2  Rajasthan Royals  Chennai Super Kings     9     4
# ...          ...     ...               ...                  ...   ...   ...
# 170644     11316       1  Rajasthan Royals  Chennai Super Kings    10     6
# 170645     11316       1  Rajasthan Royals  Chennai Super Kings    11     1
# 170646     11316       1  Rajasthan Royals  Chennai Super Kings    11     2
# 170648     11316       1  Rajasthan Royals  Chennai Super Kings    11     4
# 170649     11316       1  Rajasthan Royals  Chennai Super Kings    11     5
#
# ...

# %%
Balls_taken_by_steve_smith_per_match
# Out:
# match_id  ball
# 467       1       2
#           2       4
#           3       3
#           4       4
#           5       2
#           6       5
# 494       1       2
#           2       1
#           3       2
#           4       2
#           6       1
# 533       1       2
#           2       1
#           3       1
#           5       2
#           6       1
# 563       2       1
#           3       2
#           4       1
#           5       1
#           6       1
# 11148     1       7
#           2       3
#           3       6
#           4       4
#           5       5
#           6       5
#           7       2
#           8       1
# 11316     1       4
#           2       4
#           3       4
#           4       4
#           5       3
#           6       3
# dtype: int64

# %%
Steve_Smith_Strike_Rate['batsman_runs'].value_counts()
# Out:
# 1    46
# 0    36
# 2     9
# 4     5
# Name: batsman_runs, dtype: int64

# %% [markdown]
# # from Match_id Steve Smith has played 6 matches

# %%
Steve_Smith_Strike_Rate['match_id'].value_counts()
# Out:
# 11148    33
# 11316    22
# 467      20
# 494       8
# 533       7
# 563       6
# Name: match_id, dtype: int64

# %%
Steve_Smith_runs_per_match=Steve_Smith_Strike_Rate.groupby('match_id')['batsman_runs']

# %%
Steve_Smith_runs_per_match.sum()
# Out:
# match_id
# 467      19
# 494       9
# 533       6
# 563       4
# 11148    31
# 11316    15
# Name: batsman_runs, dtype: int64

# %% [markdown]
# # # Balls_taken_by_steve_smith_per_match

# %%
Balls_taken_by_steve_smith_per_match=Steve_Smith_Strike_Rate.groupby(['match_id','ball']).size()

# %%
Balls_taken_by_steve_smith_per_match
# Out:
# match_id  ball
# 467       1       2
#           2       4
#           3       3
#           4       4
#           5       2
#           6       5
# 494       1       2
#           2       1
#           3       2
#           4       2
#           6       1
# 533       1       2
#           2       1
#           3       1
#           5       2
#           6       1
# 563       2       1
#           3       2
#           4       1
#           5       1
#           6       1
# 11148     1       7
#           2       3
#           3       6
#           4       4
#           5       5
#           6       5
#           7       2
#           8       1
# 11316     1       4
#           2       4
#           3       4
#           4       4
#           5       3
#           6       3
# dtype: int64

# %% [markdown]
# # To calculate strike_Rate, we need to divide Runs scored /Balls taken

# %%
print("In match_id--->467,Steve Smith scored 19 runs from 20 balls and his strike rate was",(9/20)*100)
print("In match_id--->494,Steve Smith scored 9 runs from 8 balls and his strike rate was",(9/8)*100)
print("In match_id--->533,Steve Smith scored 6 runs from 7 balls and his strike rate was",(6/7)*100)
print("In match_id--->563,Steve Smith scored 4 runs from 6 balls and his strike rate was",(4/6)*100)
print("In match_id--->11148,Steve Smith scored 31 runs from 33 balls and his strike rate was",(31/33)*100)
print("In match_id--->11316,Steve Smith scored 15 runs from 22 balls and his strike rate was",(15/22)*100)
# Out:
# In match_id--->467,Steve Smith scored 19 runs from 20 balls and his strike rate was 45.0
# In match_id--->494,Steve Smith scored 9 runs from 8 balls and his strike rate was 112.5
# In match_id--->533,Steve Smith scored 6 runs from 7 balls and his strike rate was 85.71428571428571
# In match_id--->563,Steve Smith scored 4 runs from 6 balls and his strike rate was 66.66666666666666
# In match_id--->11148,Steve Smith scored 31 runs from 33 balls and his strike rate was 93.93939393939394
# In match_id--->11316,Steve Smith scored 15 runs from 22 balls and his strike rate was 68.18181818181817

# %% [markdown]
# # Taking the average  strike_rate from 6 matches

# %%
print("Average strike_rate of Steve_smith from 6 matches was",(45.0+112.5+85.714+66.67+93.939+68.1818)//6)
# Out:
# Average strike_rate of Steve_smith from 6 matches was 78.0

# %%
sns.distplot(Balls_taken_by_steve_smith_per_match)

# %% [markdown]
# # Steve Smith against Csk bowlers

# %%
sns.boxplot(x='bowler',y='total_runs',data=Steve_Smith_Strike_Rate)

# %%
x=[19,9,6,4,31,15]
y=[20,8,7,6,33,22]
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='purple',lw=2,ls='--')
#plt.bar(x,y)

# %%
x=[19,9,6,4,31,15]
y=[20,8,7,6,33,22]
plt.bar(x,y)
plt.xlabel("Balls taken By Steve Smith from his six matches against csk")
plt.ylabel("Runs scored By Steve Smith from his six matches against csk")
plt.title("Balls Vs Runs scored")
# Out:
# Text(0.5, 1.0, 'Balls Vs Runs scored')

# %%
sns.countplot(Steve_Smith_Strike_Rate.groupby(['batsman_runs','ball']).size())

# %%
import sweetviz
Steve_Smith_VS_Bowlers=sweetviz.analyze([Steve_Smith_Strike_Rate,'Steve_Smith_Strike_Rate'])
# Out:
# :FEATURES DONE:                    |                     | [  0%]   00:06  -> (00:00 left)
# :PAIRWISE DONE:                    |█████████████████████| [100%]   00:00  -> (00:00 left)
# Creating Associations graph... DONE!

# %%
Steve_Smith_VS_Bowlers.show_html()

# %% [markdown]
# # From my analysing,
# # 1.CSk will win the match
# # 2.40-49 runs ll be scored by RR in PP
# # 3.Deepak chahar Economy rate ll be 7.34-8.2
# # 4.Jofra Archer ll take around 1-2 wickets
# # 5. Steve smith strike rate ll less than 120 from my analysis
# # These results are solely based on my analysis.Don't forget this year IPL has been played in UAE.So Data's from the past ll be contrary to the current stats.
