# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
Matches=pd.read_csv("matches.csv")

# %%
Matches
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
Matches.shape
# Out:
# (756, 18)

# %% [markdown]
# # How many rows and columns are there?

# %%
Matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
Matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
print("No of Rows are:",len(Matches))
print("No of columns are:",len(Matches.columns))
# Out:
# No of Rows are: 756
# No of columns are: 18

# %%
Matches.describe
# Out:
# <bound method NDFrame.describe of         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %% [markdown]
# # 756 rows are there that means we have details 756 matches that takes place between 2008-2019

# %%
print("No of matches that takes place between 2008-2019 were:",len(Matches))
# Out:
# No of matches that takes place between 2008-2019 were: 756

# %% [markdown]
# # It looks like between 2011-2013.Total no matches exceeds 70.That because in these periods(2011-2013)there were 10 teams(kochi tuskers kerala and pune warriors india were the new additions

# %%
year_wise_analysing=Matches.groupby('season')
year_wise_analysing.count()
year_wise_analysing['id'].count().plot(kind='bar')

# %%
year_wise_analysing['id'].count()
# Out:
# season
# 2008    58
# 2009    57
# 2010    60
# 2011    73
# 2012    74
# 2013    76
# 2014    60
# 2015    59
# 2016    60
# 2017    59
# 2018    60
# 2019    60
# Name: id, dtype: int64

# %%
Matches.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %% [markdown]
# # from the below plot we can find huge missing values are there in umpire 3 columns .we can remove the column it will not create a impact on predicting the matches.

# %%
sns.heatmap(Matches.isnull(),yticklabels=False,cbar=False,cmap='PiYG')

# %%
Matches.head(2)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   player_of_match                                      venue         umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2 umpire3
# 0  NJ Llong     NaN
# 1    S Ravi     NaN

# %% [markdown]
# #  Removed the columns containing more missing values and have less impact on the predicting matches

# %%
Matches=Matches.drop(['umpire3','city'],axis=1)

# %%
Matches.head(2)
# Out:
#    id  season        date                team1                        team2  \
# 0   1    2017  2017-04-05  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1   2    2017  2017-04-06       Mumbai Indians       Rising Pune Supergiant
#
#                    toss_winner toss_decision  result  dl_applied  \
# 0  Royal Challengers Bangalore         field  normal           0
# 1       Rising Pune Supergiant         field  normal           0
#
#                    winner  win_by_runs  win_by_wickets player_of_match  \
# 0     Sunrisers Hyderabad           35               0    Yuvraj Singh
# 1  Rising Pune Supergiant            0               7       SPD Smith
#
#                                        venue         umpire1   umpire2
# 0  Rajiv Gandhi International Stadium, Uppal     AY Dandekar  NJ Llong
# 1    Maharashtra Cricket Association Stadium  A Nand Kishore    S Ravi

# %%
sns.heatmap(Matches.isnull(),yticklabels=False,cbar=False,cmap='PiYG')

# %% [markdown]
# # Today's match is between DC and CSK.so we only want information between the matches that take place between them

# %%
Matches
# Out:
#         id  season        date                        team1  \
# 0        1    2017  2017-04-05          Sunrisers Hyderabad
# 1        2    2017  2017-04-06               Mumbai Indians
# 2        3    2017  2017-04-07                Gujarat Lions
# 3        4    2017  2017-04-08       Rising Pune Supergiant
# 4        5    2017  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...         ...                          ...
# 751  11347    2019    05/05/19        Kolkata Knight Riders
# 752  11412    2019    07/05/19          Chennai Super Kings
# 753  11413    2019    08/05/19          Sunrisers Hyderabad
# 754  11414    2019    10/05/19               Delhi Capitals
# 755  11415    2019    12/05/19               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1         Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %% [markdown]
# # At First we need to change the name of Delhi daredevils to Delhi capitals

# %%
Matches['team1'].replace('Delhi Daredevils','Delhi Capitals',inplace=True)

# %%
Matches['team2'].replace('Delhi Daredevils','Delhi Capitals',inplace=True)

# %%
Matches['winner'].replace('Delhi Daredevils','Delhi Capitals',inplace=True)

# %%
Matches['toss_winner'].replace('Delhi Daredevils','Delhi Capitals',inplace=True)

# %%
Matches
# Out:
#         id  season        date                        team1  \
# 0        1    2017  2017-04-05          Sunrisers Hyderabad
# 1        2    2017  2017-04-06               Mumbai Indians
# 2        3    2017  2017-04-07                Gujarat Lions
# 3        4    2017  2017-04-08       Rising Pune Supergiant
# 4        5    2017  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...         ...                          ...
# 751  11347    2019    05/05/19        Kolkata Knight Riders
# 752  11412    2019    07/05/19          Chennai Super Kings
# 753  11413    2019    08/05/19          Sunrisers Hyderabad
# 754  11414    2019    10/05/19               Delhi Capitals
# 755  11415    2019    12/05/19               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1         Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
DC_CSK1=Matches.loc[(Matches['team1']=='Delhi Capitals')&(Matches['team2'] =='Chennai Super Kings')]

# %%
DC_CSK2=Matches.loc[(Matches['team2']=='Delhi Capitals')&(Matches['team1'] =='Chennai Super Kings')]

# %%
DC_CSK=DC_CSK1.append(DC_CSK2)

# %% [markdown]
# #   Complete details of matches that takes place between DC and CSK

# %%
DC_CSK
# Out:
#         id  season        date                team1                team2  \
# 86      87    2008  2008-05-08       Delhi Capitals  Chennai Super Kings
# 124    125    2009  2009-04-23       Delhi Capitals  Chennai Super Kings
# 184    185    2010  2010-03-19       Delhi Capitals  Chennai Super Kings
# 363    364    2012  2012-05-12       Delhi Capitals  Chennai Super Kings
# 482    483    2014  2014-05-05       Delhi Capitals  Chennai Super Kings
# 687   7945    2018    18/05/18       Delhi Capitals  Chennai Super Kings
# 700  11141    2019    26/03/19       Delhi Capitals  Chennai Super Kings
# 754  11414    2019    10/05/19       Delhi Capitals  Chennai Super Kings
# 78      79    2008  2008-05-02  Chennai Super Kings       Delhi Capitals
# 140    141    2009  2009-05-02  Chennai Super Kings       Delhi Capitals
# 223    224    2010  2010-04-15  Chennai Super Kings       Delhi Capitals
# 288    289    2011  2011-05-12  Chennai Super Kings       Delhi Capitals
# ...

# %% [markdown]
# # It looks like DC and CSK played 21 matches against each other

# %%
won_by_runs_wickest=DC_CSK.groupby('id')

# %%
won_by_runs_wickest.sum()
# Out:
#        season  dl_applied  win_by_runs  win_by_wickets
# id
# 79       2008           0            0               8
# 87       2008           0            0               4
# 125      2009           0            9               0
# 141      2009           0           18               0
# 185      2010           0            0               5
# 224      2010           0            0               6
# 289      2011           0           18               0
# 318      2012           0            0               8
# 364      2012           0            0               9
# 380      2012           0           86               0
# 404      2013           0           86               0
# 446      2013           0           33               0
# 465      2014           0           93               0
# 483      2014           0            0               8
# 519      2015           0            1               0
# 565      2015           0            0               6
# ...

# %%
DC_CSK['id'].value_counts()
# Out:
# 318      1
# 79       1
# 289      1
# 483      1
# 11141    1
# 519      1
# 7945     1
# 364      1
# 141      1
# 11341    1
# 465      1
# 125      1
# 446      1
# 404      1
# 565      1
# 11414    1
# 87       1
# 185      1
# 7923     1
# 380      1
# 224      1
# Name: id, dtype: int64

# %%
DC_CSK.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21 entries, 86 to 745
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21 non-null     int64
#  1   season           21 non-null     int64
#  2   date             21 non-null     object
#  3   team1            21 non-null     object
#  4   team2            21 non-null     object
#  5   toss_winner      21 non-null     object
#  6   toss_decision    21 non-null     object
#  7   result           21 non-null     object
#  8   dl_applied       21 non-null     int64
#  9   winner           21 non-null     object
#  10  win_by_runs      21 non-null     int64
#  11  win_by_wickets   21 non-null     int64
#  12  player_of_match  21 non-null     object
#  13  venue            21 non-null     object
#  14  umpire1          21 non-null     object
#  15  umpire2          21 non-null     object
# dtypes: int64(5), object(11)
# ...

# %%
DC_CSK.describe
# Out:
# <bound method NDFrame.describe of         id  season        date                team1                team2  \
# 86      87    2008  2008-05-08       Delhi Capitals  Chennai Super Kings
# 124    125    2009  2009-04-23       Delhi Capitals  Chennai Super Kings
# 184    185    2010  2010-03-19       Delhi Capitals  Chennai Super Kings
# 363    364    2012  2012-05-12       Delhi Capitals  Chennai Super Kings
# 482    483    2014  2014-05-05       Delhi Capitals  Chennai Super Kings
# 687   7945    2018    18/05/18       Delhi Capitals  Chennai Super Kings
# 700  11141    2019    26/03/19       Delhi Capitals  Chennai Super Kings
# 754  11414    2019    10/05/19       Delhi Capitals  Chennai Super Kings
# 78      79    2008  2008-05-02  Chennai Super Kings       Delhi Capitals
# 140    141    2009  2009-05-02  Chennai Super Kings       Delhi Capitals
# 223    224    2010  2010-04-15  Chennai Super Kings       Delhi Capitals
# ...

# %%
print("No of matches that takes place between MI and KKR:",len(DC_CSK))
# Out:
# No of matches that takes place between MI and KKR: 21

# %% [markdown]
# # Below plot gives the details of the match that takes place between DC and CSK

# %%
sns.pairplot(DC_CSK)

# %% [markdown]
# # Now Time to answer the questions that were asked in the widhya ipl

# %%
DC_CSK['toss_winner'].value_counts()
# Out:
# Chennai Super Kings    12
# Delhi Capitals          9
# Name: toss_winner, dtype: int64

# %% [markdown]
# # Sometimes Toss plays an crucial role in deciding the winner.DC won the Toss 9 times and CSK won it 12 times

# %%
DC_CSK['toss_winner'].value_counts().plot(kind='bar')

# %%
print("No of times toss won by both teams:")
DC_CSK['toss_winner'].value_counts()
# Out:
# No of times toss won by both teams:
# Chennai Super Kings    12
# Delhi Capitals          9
# Name: toss_winner, dtype: int64

# %% [markdown]
# # From 21 matches Delhi Capitals win 4 Times by Batting first and 2 times by Batting second whereas Chennai Super Kings win 6 times by batting first and 9 times by batting second.

# %%
import sys
sys.setrecursionlimit(10000) 
sns.set({'figure.figsize':(15,5)})
sns.countplot(x='toss_decision',hue='winner',data=DC_CSK,palette='RdBu_r')

# %%
DC_CSK['winner'].value_counts()
# Out:
# Chennai Super Kings    15
# Delhi Capitals          6
# Name: winner, dtype: int64

# %% [markdown]
# # CSK win 15 times against Delhi captials and DC win 6 times against csk.it's clear that CSk dominating DC

# %%
DC_CSK['winner'].value_counts().plot(kind='bar')

# %% [markdown]
# # Complete details DC_CSK using sweetviz library

# %%
import sweetviz 
my_report=sweetviz.analyze([DC_CSK,"DC_CSK"])
# Out:
# :FEATURES DONE:                    |                     | [  0%]   00:08  -> (00:00 left)
# :PAIRWISE DONE:                    |█████████████████████| [100%]   00:00  -> (00:00 left)
# Creating Associations graph... DONE!

# %%
my_report.show_html()

# %% [markdown]
# # Now it's time to move into deliveries data sets

# %%
Deliveries=pd.read_csv("deliveries.csv")

# %%
Deliveries.head(5)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
Deliveries.tail(5)
# Out:
#         match_id  inning         batting_team    bowling_team  over  ball  \
# 179073     11415       2  Chennai Super Kings  Mumbai Indians    20     2
# 179074     11415       2  Chennai Super Kings  Mumbai Indians    20     3
# 179075     11415       2  Chennai Super Kings  Mumbai Indians    20     4
# 179076     11415       2  Chennai Super Kings  Mumbai Indians    20     5
# 179077     11415       2  Chennai Super Kings  Mumbai Indians    20     6
#
#           batsman non_striker      bowler  is_super_over  ...  bye_runs  \
# 179073  RA Jadeja   SR Watson  SL Malinga              0  ...         0
# 179074  SR Watson   RA Jadeja  SL Malinga              0  ...         0
# 179075  SR Watson   RA Jadeja  SL Malinga              0  ...         0
# 179076  SN Thakur   RA Jadeja  SL Malinga              0  ...         0
# 179077  SN Thakur   RA Jadeja  SL Malinga              0  ...         0
#
#         legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
Deliveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %% [markdown]
# # At First we need to change the name of Delhi daredevils to Delhi capitals#

# %%
Deliveries['batting_team'].replace('Delhi Daredevils','Delhi Capitals',inplace=True)

# %%
Deliveries['bowling_team'].replace('Delhi Daredevils','Delhi Capitals',inplace=True)

# %%
Deliveries
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %% [markdown]
# # Filtering the match details that only takes place between Delhi capitals and Chennai Super Kings

# %%
Delhi_Chennai1=Deliveries.loc[(Deliveries['batting_team' ] =='Delhi Capitals' ) & (Deliveries['bowling_team'] == 'Chennai Super Kings')]

# %%
Delhi_Chennai2=Deliveries.loc[(Deliveries['bowling_team' ] =='Delhi Capitals' ) & (Deliveries['batting_team'] == 'Chennai Super Kings')]

# %%
Delhi_Chennai=Delhi_Chennai1.append(Delhi_Chennai2)

# %%
Delhi_Chennai
# Out:
#         match_id  inning         batting_team         bowling_team  over  \
# 18498         79       2       Delhi Capitals  Chennai Super Kings     1
# 18499         79       2       Delhi Capitals  Chennai Super Kings     1
# 18500         79       2       Delhi Capitals  Chennai Super Kings     1
# 18501         79       2       Delhi Capitals  Chennai Super Kings     1
# 18502         79       2       Delhi Capitals  Chennai Super Kings     1
# ...          ...     ...                  ...                  ...   ...
# 178825     11414       2  Chennai Super Kings       Delhi Capitals    19
# 178826     11414       2  Chennai Super Kings       Delhi Capitals    19
# 178827     11414       2  Chennai Super Kings       Delhi Capitals    19
# 178828     11414       2  Chennai Super Kings       Delhi Capitals    19
# 178829     11414       2  Chennai Super Kings       Delhi Capitals    19
#
#         ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# ...

# %%
Delhi_Chennai['match_id'].value_counts()
# Out:
# 87       251
# 7923     250
# 446      248
# 519      248
# 185      248
# 289      246
# 141      246
# 7945     246
# 11141    246
# 125      246
# 483      244
# 79       244
# 224      242
# 11414    239
# 404      234
# 380      229
# 11341    223
# 565      220
# 465      219
# 364      218
# 318      204
# Name: match_id, dtype: int64

# %%
Delhi_Chennai.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4991 entries, 18498 to 178829
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   match_id          4991 non-null   int64
#  1   inning            4991 non-null   int64
#  2   batting_team      4991 non-null   object
#  3   bowling_team      4991 non-null   object
#  4   over              4991 non-null   int64
#  5   ball              4991 non-null   int64
#  6   batsman           4991 non-null   object
#  7   non_striker       4991 non-null   object
#  8   bowler            4991 non-null   object
#  9   is_super_over     4991 non-null   int64
#  10  wide_runs         4991 non-null   int64
#  11  bye_runs          4991 non-null   int64
#  12  legbye_runs       4991 non-null   int64
#  13  noball_runs       4991 non-null   int64
#  14  penalty_runs      4991 non-null   int64
#  15  batsman_runs      4991 non-null   int64
# ...

# %%
Delhi_Chennai.describe
# Out:
# <bound method NDFrame.describe of         match_id  inning         batting_team         bowling_team  over  \
# 18498         79       2       Delhi Capitals  Chennai Super Kings     1
# 18499         79       2       Delhi Capitals  Chennai Super Kings     1
# 18500         79       2       Delhi Capitals  Chennai Super Kings     1
# 18501         79       2       Delhi Capitals  Chennai Super Kings     1
# 18502         79       2       Delhi Capitals  Chennai Super Kings     1
# ...          ...     ...                  ...                  ...   ...
# 178825     11414       2  Chennai Super Kings       Delhi Capitals    19
# 178826     11414       2  Chennai Super Kings       Delhi Capitals    19
# 178827     11414       2  Chennai Super Kings       Delhi Capitals    19
# 178828     11414       2  Chennai Super Kings       Delhi Capitals    19
# 178829     11414       2  Chennai Super Kings       Delhi Capitals    19
#
# ...

# %% [markdown]
# # Check For any Null values

# %%
Delhi_Chennai.isnull().sum()
# Out:
# match_id               0
# inning                 0
# batting_team           0
# bowling_team           0
# over                   0
# ball                   0
# batsman                0
# non_striker            0
# bowler                 0
# is_super_over          0
# wide_runs              0
# bye_runs               0
# legbye_runs            0
# noball_runs            0
# penalty_runs           0
# batsman_runs           0
# extra_runs             0
# total_runs             0
# player_dismissed    4743
# dismissal_kind      4743
# fielder             4794
# dtype: int64

# %% [markdown]
# # Looks like we have huge null(NaN) values in  player_dismissed,dismissal_kind,fielder columns

# %%
sns.heatmap(Delhi_Chennai.isnull(),yticklabels=False,cbar=False,cmap='PiYG')

# %% [markdown]
# # Replace the NaN values to 0

# %%
Delhi_Chennai.fillna(0,inplace=True)

# %% [markdown]
# # Now it's clear

# %%
sns.heatmap(Delhi_Chennai.isnull(),yticklabels=False,cbar=False,cmap='PiYG')

# %% [markdown]
# # # Let's try covariance to find relation among features

# %%
Delhi_Chennai.cov()
# Out:
#                    match_id    inning        over       ball  is_super_over  \
# match_id       1.754543e+07  4.715296  276.122886 -23.112409            0.0
# inning         4.715296e+00  0.249569   -0.169879  -0.009586            0.0
# over           2.761229e+02 -0.169879   31.896161  -0.054694            0.0
# ball          -2.311241e+01 -0.009586   -0.054694   3.209651            0.0
# is_super_over  0.000000e+00  0.000000    0.000000   0.000000            0.0
# wide_runs     -1.091467e+01 -0.000089   -0.001767  -0.010851            0.0
# bye_runs      -6.937502e+00  0.000480    0.000583  -0.001562            0.0
# legbye_runs    1.958414e+00 -0.000510   -0.008463  -0.017869            0.0
# noball_runs   -1.345614e-01 -0.000627   -0.003391   0.000362            0.0
# penalty_runs   0.000000e+00  0.000000    0.000000   0.000000            0.0
# batsman_runs   1.149273e+02 -0.016629    0.686043   0.026208            0.0
# ...

# %% [markdown]
# # it's diffult to interpret covariance.Let's try correlation.Correlation clearly mentions using discrete values 1=positively correlated,-1=Negatively correlated,0=No correlation.

# %%
Delhi_Chennai.corr()
# Out:
#                match_id    inning      over      ball  is_super_over  \
# match_id       1.000000  0.002253  0.011672 -0.003080            NaN
# inning         0.002253  1.000000 -0.060211 -0.010711            NaN
# over           0.011672 -0.060211  1.000000 -0.005406            NaN
# ball          -0.003080 -0.010711 -0.005406  1.000000            NaN
# is_super_over       NaN       NaN       NaN       NaN            NaN
# wide_runs     -0.011187 -0.000768 -0.001343 -0.026003            NaN
# bye_runs      -0.015931  0.009241  0.000993 -0.008386            NaN
# legbye_runs    0.002134 -0.004656 -0.006840 -0.045527            NaN
# noball_runs   -0.000551 -0.021528 -0.010303  0.003466            NaN
# penalty_runs        NaN       NaN       NaN       NaN            NaN
# batsman_runs   0.017317 -0.021010  0.076670  0.009233            NaN
# extra_runs    -0.011323 -0.004417 -0.006831 -0.049419            NaN
# total_runs     0.014837 -0.021855  0.074881 -0.001302            NaN
#
# ...

# %% [markdown]
# # # Ball by Ball Details of DC VS CSK From 21 matches

# %%
Delhi_Chennai
# Out:
#         match_id  inning         batting_team         bowling_team  over  \
# 18498         79       2       Delhi Capitals  Chennai Super Kings     1
# 18499         79       2       Delhi Capitals  Chennai Super Kings     1
# 18500         79       2       Delhi Capitals  Chennai Super Kings     1
# 18501         79       2       Delhi Capitals  Chennai Super Kings     1
# 18502         79       2       Delhi Capitals  Chennai Super Kings     1
# ...          ...     ...                  ...                  ...   ...
# 178825     11414       2  Chennai Super Kings       Delhi Capitals    19
# 178826     11414       2  Chennai Super Kings       Delhi Capitals    19
# 178827     11414       2  Chennai Super Kings       Delhi Capitals    19
# 178828     11414       2  Chennai Super Kings       Delhi Capitals    19
# 178829     11414       2  Chennai Super Kings       Delhi Capitals    19
#
#         ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# ...

# %%
Complete_Details=Delhi_Chennai.groupby('match_id')

# %%
Complete_Details.sum()
# Out:
#           inning  over  ball  is_super_over  wide_runs  bye_runs  legbye_runs  \
# match_id
# 79           362  2478   890              0          7         1            1
# 87           376  2618   920              0         10         1           10
# 125          371  2572   882              0          9         0            6
# 141          367  2568   882              0          5         4            2
# 185          371  2555   912              0         13         0            6
# 224          358  2480   881              0         15         4            0
# 289          370  2603   882              0          6         0           11
# 318          284  1849   725              0          4         1            2
# 364          311  2080   780              0          6         0            2
# 380          335  2235   828              0         12         1            4
# 404          343  2301   846              0          9         0            4
# ...

# %% [markdown]
# # From the correlation plot we can clearly see that extra runs,wide runs ,bye runs are correlated and apart from that batsman runs column and total_runs columns are highly correlated

# %%
plt.figure(figsize=(10,5))
sns.heatmap(Delhi_Chennai.corr(),yticklabels=True,annot=True)

# %% [markdown]
# # How Many Runs will CSK score in this match?

# %%
Delhi_Chennai2
# Out:
#         match_id  inning         batting_team    bowling_team  over  ball  \
# 18372         79       1  Chennai Super Kings  Delhi Capitals     1     1
# 18373         79       1  Chennai Super Kings  Delhi Capitals     1     2
# 18374         79       1  Chennai Super Kings  Delhi Capitals     1     3
# 18375         79       1  Chennai Super Kings  Delhi Capitals     1     4
# 18376         79       1  Chennai Super Kings  Delhi Capitals     1     5
# ...          ...     ...                  ...             ...   ...   ...
# 178825     11414       2  Chennai Super Kings  Delhi Capitals    19     2
# 178826     11414       2  Chennai Super Kings  Delhi Capitals    19     3
# 178827     11414       2  Chennai Super Kings  Delhi Capitals    19     4
# 178828     11414       2  Chennai Super Kings  Delhi Capitals    19     5
# 178829     11414       2  Chennai Super Kings  Delhi Capitals    19     6
#
#            batsman non_striker      bowler  is_super_over  ...  bye_runs  \
# ...

# %%
Delhi_Chennai2.head(2)
# Out:
#        match_id  inning         batting_team    bowling_team  over  ball  \
# 18372        79       1  Chennai Super Kings  Delhi Capitals     1     1
# 18373        79       1  Chennai Super Kings  Delhi Capitals     1     2
#
#           batsman non_striker      bowler  is_super_over  ...  bye_runs  \
# 18372    PA Patel  SP Fleming  GD McGrath              0  ...         0
# 18373  SP Fleming    PA Patel  GD McGrath              0  ...         0
#
#        legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# 18372            0            0             0             1           0
# 18373            0            0             0             0           0
#
#        total_runs  player_dismissed dismissal_kind fielder
# 18372           1               NaN            NaN     NaN
# 18373           0               NaN            NaN     NaN
#
# [2 rows x 21 columns]

# %%
Csk_Runs=Delhi_Chennai2['total_runs'].value_counts()

# %% [markdown]
# # ways of Runs scored by csk  (1's-1021,2's=185,4's=304,6's=123)

# %%
Csk_Runs
# Out:
# 1     1021
# 0      897
# 4      304
# 2      185
# 6      123
# 3       16
# 5        3
# 8        3
# 10       1
# Name: total_runs, dtype: int64

# %%
Delhi_Chennai2['total_runs'].sum()
# Out:
# 3442

# %% [markdown]
# # Match wise Runs scored by Csk Against DC

# %%
Csk_Runs_match_Wise=Delhi_Chennai2.groupby('match_id')['total_runs']

# %%
Csk_Runs_match_Wise.sum()
# Out:
# match_id
# 79       169
# 87       188
# 125      180
# 141      163
# 185      190
# 224      112
# 289      176
# 318      110
# 364      115
# 380      222
# 404      169
# 446      168
# 465      177
# 483      181
# 519      150
# 565      119
# 7923     218
# 7945     130
# 11141    157
# 11341    186
# 11414    162
# Name: total_runs, dtype: int64

# %% [markdown]
# # Below plots used to tell whether csk repeated same score in their 21 matches.They scored 169 runs two times agaisnt DC

# %%
sns.set()
plt.figure(figsize=(26,5))
sns.countplot(Csk_Runs_match_Wise.sum(),data=Delhi_Chennai2)

# %% [markdown]
# # Inning wise Details OF runs scored by CSK from 21 matches against DC.Csck score 2139 runs by batting first and 1303 by batting second against DC

# %%
Csk_Runs_inning_Wise=Delhi_Chennai2.groupby('inning')['total_runs']

# %%
Csk_Runs_inning_Wise.sum()
# Out:
# inning
# 1    2139
# 2    1303
# Name: total_runs, dtype: int64

# %%
sns.set()
plt.figure(figsize=(26,5))
sns.countplot(Csk_Runs_inning_Wise.sum(),data=Delhi_Chennai2)

# %%
print("Csk scored a Total of 3442 from 21 matches against Dc")
# Out:
# Csk scored a Total of 3442 from 21 matches against Dc

# %%
print("Average runs score by csk in a single match against Dc:",Delhi_Chennai2['total_runs'].sum()//21)
# Out:
# Average runs score by csk in a single match against Dc: 163

# %% [markdown]
# # Runs scored by csk (1's-1021,2's=185,4's=304,6's=123)

# %%
sns.countplot(x='total_runs',data=Delhi_Chennai2)

# %% [markdown]
# # How many wickets will csk take from 91st ball to 120 ball?

# %%
Delhi_Chennai1
# Out:
#         match_id  inning    batting_team         bowling_team  over  ball  \
# 18498         79       2  Delhi Capitals  Chennai Super Kings     1     1
# 18499         79       2  Delhi Capitals  Chennai Super Kings     1     2
# 18500         79       2  Delhi Capitals  Chennai Super Kings     1     3
# 18501         79       2  Delhi Capitals  Chennai Super Kings     1     4
# 18502         79       2  Delhi Capitals  Chennai Super Kings     1     5
# ...          ...     ...             ...                  ...   ...   ...
# 178709     11414       1  Delhi Capitals  Chennai Super Kings    20     2
# 178710     11414       1  Delhi Capitals  Chennai Super Kings    20     3
# 178711     11414       1  Delhi Capitals  Chennai Super Kings    20     4
# 178712     11414       1  Delhi Capitals  Chennai Super Kings    20     5
# 178713     11414       1  Delhi Capitals  Chennai Super Kings    20     6
#
#           batsman non_striker     bowler  is_super_over  ...  bye_runs  \
# ...

# %%
Wickets_Taken_By_Csk_after_15_Overs=Delhi_Chennai1.loc[(Delhi_Chennai1['over']>=15)]

# %%
Wickets_Taken_By_Csk_after_15_Overs
# Out:
#         match_id  inning    batting_team         bowling_team  over  ball  \
# 18585         79       2  Delhi Capitals  Chennai Super Kings    15     1
# 18586         79       2  Delhi Capitals  Chennai Super Kings    15     2
# 18587         79       2  Delhi Capitals  Chennai Super Kings    15     3
# 18588         79       2  Delhi Capitals  Chennai Super Kings    15     4
# 18589         79       2  Delhi Capitals  Chennai Super Kings    15     5
# ...          ...     ...             ...                  ...   ...   ...
# 178709     11414       1  Delhi Capitals  Chennai Super Kings    20     2
# 178710     11414       1  Delhi Capitals  Chennai Super Kings    20     3
# 178711     11414       1  Delhi Capitals  Chennai Super Kings    20     4
# 178712     11414       1  Delhi Capitals  Chennai Super Kings    20     5
# 178713     11414       1  Delhi Capitals  Chennai Super Kings    20     6
#
#                batsman     non_striker     bowler  is_super_over  ...  \
# ...

# %%
s=Wickets_Taken_By_Csk_after_15_Overs.groupby('match_id')['dismissal_kind']

# %%
s.sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-286-1597a9ac297c> in <module>
# ----> 1 s.sum()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in f(self, **kwargs)
#    1384
#    1385                 # apply a non-cython aggregation
# -> 1386                 result = self.aggregate(lambda x: npfunc(x, axis=self.axis))
#    1387                 return result
#    1388
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, *args, **kwargs)
#     263
#     264             try:
# --> 265                 return self._python_agg_general(func, *args, **kwargs)
#     266             except (ValueError, KeyError):
#     267                 # TODO: KeyError is raised in _python_agg_general,
#
# ...

# %%
wickets_91st_120th_Ball=Wickets_Taken_By_Csk_after_15_Overs['dismissal_kind']

# %%
wickets_91st_120th_Ball.value_counts()
# Out:
# caught     28
# bowled     13
# run out     4
# stumped     2
# lbw         1
# Name: dismissal_kind, dtype: int64

# %%
print("csk has taken a Total Of 48 wickets From 91st-120th balls in 21 matches against DC")
# Out:
# csk has taken a Total Of 48 wickets From 91st-120th balls in 21 matches against DC

# %%
print("Average Wickets taken by csk from(91st-120th balls)against DC:",48//21)
# Out:
# Average Wickets taken by csk from(91st-120th balls)against DC: 2

# %% [markdown]
# # WIckets Taken by CSK

# %%
from matplotlib import rcParams
#rcParams['figure.figsize'] = 11.7,8.27
sns.set()
plt.figure(figsize=(25,10))
sns.countplot(x='bowler',hue='dismissal_kind',data=Delhi_Chennai1)
plt.legend(loc='right')

# %% [markdown]
# # How Many NO-ball ll be bowled?

# %%
Delhi_Chennai['noball_runs'].value_counts()
# Out:
# 0    4974
# 1      17
# Name: noball_runs, dtype: int64

# %%
No_ball=Delhi_Chennai.groupby('noball_runs')

# %%
No_ball.sum()
# Out:
#              match_id  inning   over   ball  is_super_over  wide_runs  \
# noball_runs
# 0            13075697    7355  50611  17903              0        162
# 1               44016      22    156     63              0          0
#
#              bye_runs  legbye_runs  penalty_runs  batsman_runs  extra_runs  \
# noball_runs
# 0                  18          112             0          6146         292
# 1                   0            0             0            31          17
#
#              total_runs
# noball_runs
# 0                  6438
# 1                    48

# %%
No_ball_matches_details=Delhi_Chennai.loc[(Delhi_Chennai['noball_runs']==1)]

# %%
No_ball_matches_details
# Out:
#         match_id  inning         batting_team         bowling_team  over  \
# 18537         79       2       Delhi Capitals  Chennai Super Kings     7
# 18544         79       2       Delhi Capitals  Chennai Super Kings     8
# 20237         87       1       Delhi Capitals  Chennai Super Kings     2
# 20238         87       1       Delhi Capitals  Chennai Super Kings     2
# 32856        141       2       Delhi Capitals  Chennai Super Kings     2
# 43382        185       1       Delhi Capitals  Chennai Super Kings     5
# 178678     11414       1       Delhi Capitals  Chennai Super Kings    15
# 18391         79       1  Chennai Super Kings       Delhi Capitals     4
# 18392         79       1  Chennai Super Kings       Delhi Capitals     4
# 28946        125       2  Chennai Super Kings       Delhi Capitals     8
# 52926        224       1  Chennai Super Kings       Delhi Capitals    17
# 52941        224       1  Chennai Super Kings       Delhi Capitals    19
# ...

# %%
print("17 No_balls were bowled between Csk and DC from 21 matches")
# Out:
# 17 No_balls were bowled between Csk and DC from 21 matches

# %%
print("No of no_balls bowled from 21 matches:",len(No_ball_matches_details)/21)
# Out:
# No of no_balls bowled from 21 matches: 0.8095238095238095

# %%
print("Average No of no_balls bowled betwwen csk and dc from 21 matches:1")
# Out:
# Average No of no_balls bowled betwwen csk and dc from 21 matches:1

# %% [markdown]
# # Below are the bowlers who bowled No balls in 21 matches from csk and Dc

# %%
plt.figure(figsize=(20,5))
sns.countplot(x='bowler',data=No_ball_matches_details)

# %% [markdown]
# # How many ball will csk take to score 100 runs?

# %%
scoring_100_less_than_41balls=Delhi_Chennai2.loc[(Delhi_Chennai2['over']<=7)]

# %%
scoring_100_less_than_41balls
# Out:
#         match_id  inning         batting_team    bowling_team  over  ball  \
# 18372         79       1  Chennai Super Kings  Delhi Capitals     1     1
# 18373         79       1  Chennai Super Kings  Delhi Capitals     1     2
# 18374         79       1  Chennai Super Kings  Delhi Capitals     1     3
# 18375         79       1  Chennai Super Kings  Delhi Capitals     1     4
# 18376         79       1  Chennai Super Kings  Delhi Capitals     1     5
# ...          ...     ...                  ...             ...   ...   ...
# 178751     11414       2  Chennai Super Kings  Delhi Capitals     7     2
# 178752     11414       2  Chennai Super Kings  Delhi Capitals     7     3
# 178753     11414       2  Chennai Super Kings  Delhi Capitals     7     4
# 178754     11414       2  Chennai Super Kings  Delhi Capitals     7     5
# 178755     11414       2  Chennai Super Kings  Delhi Capitals     7     6
#
#              batsman   non_striker      bowler  is_super_over  ...  bye_runs  \
# ...

# %%
_less_than_41_balls=scoring_100_less_than_41balls.groupby('match_id')['total_runs']

# %%
_less_than_41_balls.sum()
# Out:
# match_id
# 79       54
# 87       71
# 125      85
# 141      58
# 185      64
# 224      44
# 289      43
# 318      47
# 364      55
# 380      64
# 404      48
# 446      61
# 465      43
# 483      52
# 519      65
# 565      24
# 7923     72
# 7945     47
# 11141    77
# 11341    37
# 11414    48
# Name: total_runs, dtype: int64

# %%
print("Csk never scored 100 runs in less than 40 balls")
# Out:
# Csk never scored 100 runs in less than 40 balls

# %%
scoring_100_on_41_60balls=Delhi_Chennai2.loc[(Delhi_Chennai2['over']<=10)]

# %%
scoring_100_on_41_60balls
# Out:
#         match_id  inning         batting_team    bowling_team  over  ball  \
# 18372         79       1  Chennai Super Kings  Delhi Capitals     1     1
# 18373         79       1  Chennai Super Kings  Delhi Capitals     1     2
# 18374         79       1  Chennai Super Kings  Delhi Capitals     1     3
# 18375         79       1  Chennai Super Kings  Delhi Capitals     1     4
# 18376         79       1  Chennai Super Kings  Delhi Capitals     1     5
# ...          ...     ...                  ...             ...   ...   ...
# 178770     11414       2  Chennai Super Kings  Delhi Capitals    10     2
# 178771     11414       2  Chennai Super Kings  Delhi Capitals    10     3
# 178772     11414       2  Chennai Super Kings  Delhi Capitals    10     4
# 178773     11414       2  Chennai Super Kings  Delhi Capitals    10     5
# 178774     11414       2  Chennai Super Kings  Delhi Capitals    10     6
#
#              batsman   non_striker      bowler  is_super_over  ...  bye_runs  \
# ...

# %%
_40_60_balls=scoring_100_on_41_60balls.groupby('match_id')['total_runs']

# %%
_40_60_balls.sum()
# Out:
# match_id
# 79        82
# 87        98
# 125      106
# 141       77
# 185      102
# 224       55
# 289       67
# 318       66
# 364       75
# 380       83
# 404       60
# 446       71
# 465       65
# 483       69
# 519       82
# 565       46
# 7923      98
# 7945      71
# 11141    101
# 11341     54
# 11414     86
# Name: total_runs, dtype: int64

# %%
print("csk scored hundred 3 times between 41-60 balls from 21 matches")
# Out:
# csk scored hundred 3 times between 41-60 balls from 21 matches

# %%
scoring_100_on_60_70balls=Delhi_Chennai2.loc[(Delhi_Chennai2['over']<=12)]

# %%
scoring_100_on_60_70balls
# Out:
#         match_id  inning         batting_team    bowling_team  over  ball  \
# 18372         79       1  Chennai Super Kings  Delhi Capitals     1     1
# 18373         79       1  Chennai Super Kings  Delhi Capitals     1     2
# 18374         79       1  Chennai Super Kings  Delhi Capitals     1     3
# 18375         79       1  Chennai Super Kings  Delhi Capitals     1     4
# 18376         79       1  Chennai Super Kings  Delhi Capitals     1     5
# ...          ...     ...                  ...             ...   ...   ...
# 178783     11414       2  Chennai Super Kings  Delhi Capitals    12     3
# 178784     11414       2  Chennai Super Kings  Delhi Capitals    12     4
# 178785     11414       2  Chennai Super Kings  Delhi Capitals    12     5
# 178786     11414       2  Chennai Super Kings  Delhi Capitals    12     6
# 178787     11414       2  Chennai Super Kings  Delhi Capitals    12     7
#
#            batsman non_striker      bowler  is_super_over  ...  bye_runs  \
# ...

# %%
_60_70_balls=scoring_100_on_60_70balls.groupby('match_id')['total_runs']

# %% [markdown]
# # Neglect the 3 hundreds that was scored between (41-60)balls apart from csk scored 6hundreds between(61-70)balls.

# %%
_60_70_balls.sum()
# Out:
# match_id
# 79       106
# 87       107
# 125      124
# 141      106
# 185      129
# 224       62
# 289       85
# 318       72
# 364       87
# 380      115
# 404       83
# 446       88
# 465       90
# 483       92
# 519       96
# 565       60
# 7923     111
# 7945      87
# 11141    113
# 11341     71
# 11414    114
# Name: total_runs, dtype: int64

# %%
print("csk scored hundred 6 times between 60-70 balls from 21 matches")
# Out:
# csk scored hundred 6 times between 60-70 balls from 21 matches

# %%
scoring_100_on_70plus_balls=Delhi_Chennai2.loc[(Delhi_Chennai2['over']>=12)]

# %%
_71_plus_balls=scoring_100_on_70plus_balls.groupby('match_id')['total_runs']

# %%
_71_plus_balls.sum()
# Out:
# match_id
# 79        71
# 87        88
# 125       67
# 141       72
# 185       71
# 224       52
# 289      103
# 318       42
# 364       32
# 380      118
# 404      100
# 446       91
# 465      100
# 483      103
# 519       62
# 565       66
# 7923     112
# 7945      53
# 11141     47
# 11341    123
# 11414     74
# Name: total_runs, dtype: int64

# %%
print("csk scored 100 seven Times after 72 balls")
print("csk scored hundred 6 times between 60-70 balls from 21 matches")
print("csk scored hundred 3 times between 41-60 balls from 21 matches")
print("Csk never scored 100 runs in less than 40 balls")
# Out:
# csk scored 100 seven Times after 72 balls
# csk scored hundred 6 times between 60-70 balls from 21 matches
# csk scored hundred 3 times between 41-60 balls from 21 matches
# Csk never scored 100 runs in less than 40 balls

# %% [markdown]
# # From my analysing and considering current matches and current form of Team and it's players.I predicted the following,
# # 1.CSk will win the match
# # 2.Csk ll scorearound 163 runs
# # 3. 4 Wickets taken by csk from(91st-120th balls)against DC
# # 4.csk ll take 60-70balls to complet 100 runs
# # 5. 1 no ball will be bowled.
# # These results are solely based on my analysis.Don't forget this year IPL has been played in UAE.So Data's from the past ll be contrary to the current stats.
